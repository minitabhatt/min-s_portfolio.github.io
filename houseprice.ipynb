# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
df =  pd.read_csv("houseprice.csv")
df.describe()
# Out:
#        Transaction date   House Age  Distance from nearest Metro station (km)  \
# count        414.000000  414.000000                                414.000000
# mean        2013.148971   17.712560                               1083.885689
# std            0.281967   11.392485                               1262.109595
# min         2012.667000    0.000000                                 23.382840
# 25%         2012.917000    9.025000                                289.324800
# 50%         2013.167000   16.100000                                492.231300
# 75%         2013.417000   28.150000                               1454.279000
# max         2013.583000   43.800000                               6488.021000
#
#        Number of convenience stores    latitude   longitude  \
# count                    414.000000  414.000000  414.000000
# mean                       4.094203   24.969030  121.533361
# std                        2.945562    0.012410    0.015347
# ...

# %%
#model = linear_model.LinearRegression()
df.columns
# Out:
# Index(['Transaction date', 'House Age',
#        'Distance from nearest Metro station (km)',
#        'Number of convenience stores', 'latitude', 'longitude',
#        'Number of bedrooms', 'House size (sqft)', 'price'],
#       dtype='object')

# %%
sns.heatmap(df.corr(), annot= True)
# Out:
# <AxesSubplot: >

# %%
df['Number of bedrooms'].value_counts().plot(kind='bar')
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
sns.pairplot(df)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.40, random_state=101)

# %%
X_train
# Out:
#      Transaction date  House Age  Distance from nearest Metro station (km)  \
# 213          2013.083        6.2                                  90.45606
# 204          2013.000       18.0                                1414.83700
# 209          2012.833       34.8                                 175.62940
# 189          2012.917       16.3                                4066.58700
# 20           2013.417        4.5                                2275.87700
# ..                ...        ...                                       ...
# 63           2013.583        2.6                                 533.47620
# 326          2013.500        4.1                                  56.47425
# 337          2012.833       31.3                                 600.86040
# 11           2013.333        6.3                                  90.45606
# 351          2012.833        4.0                                2180.24500
#
# ...

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train, y_train)
lm.score(X_test, y_test)
# Out:
# 0.6511216514835639

# %%
predictions = lr.predict(X_test)
plt.scatter(y_test, predictions)

# %%
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
from sklearn.tree import DecisionTreeRegressor 
dtr = DecisionTreeRegressor()
dtr.fit(X_train, y_train)
dtr.score(X_test, y_test)
# Out:
# 0.3654735002566598

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr = GradientBoostingRegressor()
gbr.fit(X_train, y_train)
gbr.score(X_test, y_test)
# Out:
# 0.7270485575641064

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.7451834598681746

# %%
predictions = rf.predict(X_test)
plt.scatter(y_test, predictions)

# %%
#Summary
#RandomForestRegressor model was a good model to predict house price because it was better than 
# a random guess and it outperformed the other three Regression Model. Many other Regr3ession models 
#which were not included here can also be built and tried. For future work, I would recommend this 
#RandomForestRegressor to predict house price.
